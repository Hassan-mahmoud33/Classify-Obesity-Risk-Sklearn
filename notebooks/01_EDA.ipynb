# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os

# %%
IN_KAGGLE = os.path.exists( '/kaggle/input' )

if IN_KAGGLE :
    DATA_DIR = Path( 'Multi-Class Prediction of Obesity Risk/' )

else :
    DATA_DIR = Path.cwd().parent / 'datasets' / 'raw'

train_data = pd.read_csv( DATA_DIR / 'train.csv')
test_data = pd.read_csv( DATA_DIR / 'test.csv')

train_data.shape , test_data.shape
# Out:
# ((20758, 18), (13840, 17))

# %% [markdown]
# ### EDA

# %%
train_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
train_data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
test_data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
train_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20758 non-null  int64
#  1   Gender                          20758 non-null  str
#  2   Age                             20758 non-null  float64
#  3   Height                          20758 non-null  float64
#  4   Weight                          20758 non-null  float64
#  5   family_history_with_overweight  20758 non-null  str
#  6   FAVC                            20758 non-null  str
#  7   FCVC                            20758 non-null  float64
#  8   NCP                             20758 non-null  float64
#  9   CAEC                            20758 non-null  str
#  10  SMOKE                           20758 non-null  str
#  11  CH2O                            20758 non-null  float64
# ...

# %%
train_data['Gender'].value_counts()
# Out:
# Gender
# Female    10422
# Male      10336
# Name: count, dtype: int64

# %%
print(f"min of Age = {train_data['Age'].min()}") 
print(f"max of Age = {train_data['Age'].max()}")
# Out:
# min of Age = 14.0
# max of Age = 61.0

# %%
print(f"min of Height = {train_data['Height'].min()} M") 
print(f"max of Height = {train_data['Height'].max()} M")
# Out:
# min of Height = 1.45 M
# max of Height = 1.975663 M

# %%
print(f"min of Weight = {train_data['Weight'].min()} KG") 
print(f"max of Weight = {train_data['Weight'].max()} KG")
# Out:
# min of Weight = 39.0 KG
# max of Weight = 165.057269 KG

# %%
train_data['family_history_with_overweight'].value_counts()
# Out:
# family_history_with_overweight
# yes    17014
# no      3744
# Name: count, dtype: int64

# %%
# FAVC <> Frequent consumption of high caloric food
train_data['FAVC'].value_counts()
# Out:
# FAVC
# yes    18982
# no      1776
# Name: count, dtype: int64

# %%
# FCVC <> Frequency of consumption of vegetables
train_data['FCVC'].describe()
# Out:
# count    20758.000000
# mean         2.445908
# std          0.533218
# min          1.000000
# 25%          2.000000
# 50%          2.393837
# 75%          3.000000
# max          3.000000
# Name: FCVC, dtype: float64

# %%
# NCP <> Number of main meals
train_data['NCP'].describe()
# Out:
# count    20758.000000
# mean         2.761332
# std          0.705375
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          3.000000
# max          4.000000
# Name: NCP, dtype: float64

# %%
# CAEC <> Consumption of food between meals
train_data['CAEC'].value_counts()
# Out:
# CAEC
# Sometimes     17529
# Frequently     2472
# Always          478
# no              279
# Name: count, dtype: int64

# %%
train_data['SMOKE'].value_counts()
# Out:
# SMOKE
# no     20513
# yes      245
# Name: count, dtype: int64

# %%
# CH2O <> Consumption of water per day
train_data['CH2O'].describe()
# Out:
# count    20758.000000
# mean         2.029418
# std          0.608467
# min          1.000000
# 25%          1.792022
# 50%          2.000000
# 75%          2.549617
# max          3.000000
# Name: CH2O, dtype: float64

# %%
# SCC <> Calories Consumtion Monitoring
train_data['SCC'].value_counts()
# Out:
# SCC
# no     20071
# yes      687
# Name: count, dtype: int64

# %%
# FAF <> physical Activity Frequency
train_data['FAF'].describe()
# Out:
# count    20758.000000
# mean         0.981747
# std          0.838302
# min          0.000000
# 25%          0.008013
# 50%          1.000000
# 75%          1.587406
# max          3.000000
# Name: FAF, dtype: float64

# %%
# TUE <> Time Using Technology Devices
train_data['TUE'].describe()
# Out:
# count    20758.000000
# mean         0.616756
# std          0.602113
# min          0.000000
# 25%          0.000000
# 50%          0.573887
# 75%          1.000000
# max          2.000000
# Name: TUE, dtype: float64

# %%
# CALC <> Consumption of alcohol
train_data['CALC'].value_counts()
# Out:
# CALC
# Sometimes     15066
# no             5163
# Frequently      529
# Name: count, dtype: int64

# %%
# MTRANS <> Transportation Used
train_data['MTRANS'].value_counts()
# Out:
# MTRANS
# Public_Transportation    16687
# Automobile                3534
# Walking                    467
# Motorbike                   38
# Bike                        32
# Name: count, dtype: int64

# %%
train_data['NObeyesdad'].value_counts()
# Out:
# NObeyesdad
# Obesity_Type_III       4046
# Obesity_Type_II        3248
# Normal_Weight          3082
# Obesity_Type_I         2910
# Insufficient_Weight    2523
# Overweight_Level_II    2522
# Overweight_Level_I     2427
# Name: count, dtype: int64
